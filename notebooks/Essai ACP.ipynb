# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
full_trains = pd.read_csv('../data/full_trains.csv')

# %%
full_trains
# Out:
#       year  month   service   departure_station     arrival_station  \
# 0     2017      9  National           PARIS EST                METZ
# 1     2017      9  National               REIMS           PARIS EST
# 2     2017      9  National           PARIS EST          STRASBOURG
# 3     2017      9  National          PARIS LYON         AVIGNON TGV
# 4     2017      9  National          PARIS LYON    BELLEGARDE (AIN)
# ...    ...    ...       ...                 ...                 ...
# 5457  2018      9       NaN           ANGOULEME  PARIS MONTPARNASSE
# 5458  2018      9       NaN   TOULOUSE MATABIAU  PARIS MONTPARNASSE
# 5459  2018      9       NaN  PARIS MONTPARNASSE               TOURS
# 5460  2018      9       NaN  PARIS MONTPARNASSE               LAVAL
# 5461  2018      9       NaN             ST MALO  PARIS MONTPARNASSE
#
#       journey_time_avg  total_num_trips  num_of_canceled_trains  \
# 0            85.133779              299                       0
# ...

# %%
X = full_trains[['avg_delay_late_at_departure', 'avg_delay_late_on_arrival']]

# %%
X
# Out:
#       avg_delay_late_at_departure  avg_delay_late_on_arrival
# 0                       11.550000                  13.794118
# 1                       14.653333                  13.570290
# 2                       13.694167                  21.532456
# 3                       20.988426                  26.566667
# 4                       20.963542                  23.151754
# ...                           ...                        ...
# 5457                     5.837664                  18.051064
# 5458                     5.517949                  32.032667
# 5459                     9.431944                  18.482292
# 5460                     6.712222                   9.911905
# 5461                    10.150000                  12.653333
#
# [5462 rows x 2 columns]

# %%
full_trains[full_trains.departure_station == 'ST MALO']
# Out:
#       year  month   service departure_station     arrival_station  \
# 114   2015      3  National           ST MALO  PARIS MONTPARNASSE
# 167   2015      2  National           ST MALO  PARIS MONTPARNASSE
# 405   2017     12  National           ST MALO  PARIS MONTPARNASSE
# 533   2015      4  National           ST MALO  PARIS MONTPARNASSE
# 718   2016     10  National           ST MALO  PARIS MONTPARNASSE
# 971   2016      4  National           ST MALO  PARIS MONTPARNASSE
# 1036  2015      9  National           ST MALO  PARIS MONTPARNASSE
# 1231  2016     11  National           ST MALO  PARIS MONTPARNASSE
# 1418  2016      3  National           ST MALO  PARIS MONTPARNASSE
# 1459  2015     12  National           ST MALO  PARIS MONTPARNASSE
# 1548  2016      1  National           ST MALO  PARIS MONTPARNASSE
# 1571  2016      8  National           ST MALO  PARIS MONTPARNASSE
# 1746  2015      8  National           ST MALO  PARIS MONTPARNASSE
# ...

# %%
full_trains[full_trains.service.isna()]
# Out:
#       year  month service   departure_station      arrival_station  \
# 3286  2018      6     NaN  PARIS MONTPARNASSE             POITIERS
# 3287  2018      6     NaN  PARIS MONTPARNASSE              QUIMPER
# 3288  2018      6     NaN  PARIS MONTPARNASSE               RENNES
# 3289  2018      6     NaN  PARIS MONTPARNASSE  ST PIERRE DES CORPS
# 3290  2018      6     NaN               TOURS   PARIS MONTPARNASSE
# ...    ...    ...     ...                 ...                  ...
# 5457  2018      9     NaN           ANGOULEME   PARIS MONTPARNASSE
# 5458  2018      9     NaN   TOULOUSE MATABIAU   PARIS MONTPARNASSE
# 5459  2018      9     NaN  PARIS MONTPARNASSE                TOURS
# 5460  2018      9     NaN  PARIS MONTPARNASSE                LAVAL
# 5461  2018      9     NaN             ST MALO   PARIS MONTPARNASSE
#
#       journey_time_avg  total_num_trips  num_of_canceled_trains  \
# 3286         94.334951              495                      83
# ...
