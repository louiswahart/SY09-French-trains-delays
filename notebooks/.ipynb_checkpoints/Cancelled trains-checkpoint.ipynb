# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data/full_trains_fixed.csv')

# %%
data
# Out:
#       year  month   service   departure_station     arrival_station  \
# 0     2017      9  National           PARIS EST                METZ
# 1     2017      9  National               REIMS           PARIS EST
# 2     2017      9  National           PARIS EST          STRASBOURG
# 3     2017      9  National          PARIS LYON         AVIGNON TGV
# 4     2017      9  National          PARIS LYON    BELLEGARDE (AIN)
# ...    ...    ...       ...                 ...                 ...
# 5457  2018      9  National           ANGOULEME  PARIS MONTPARNASSE
# 5458  2018      9  National   TOULOUSE MATABIAU  PARIS MONTPARNASSE
# 5459  2018      9  National  PARIS MONTPARNASSE               TOURS
# 5460  2018      9  National  PARIS MONTPARNASSE               LAVAL
# 5461  2018      9  National             ST MALO  PARIS MONTPARNASSE
#
#       journey_time_avg  total_num_trips  num_of_canceled_trains  \
# 0            85.133779              299                       0
# 1            47.064516              218                       1
# 2           116.234940              333                       1
# 3           161.089583              481                       1
# 4           164.452632              190                       0
# ...                ...              ...                     ...
# 5457        130.690840              262                       0
# 5458        263.584270              178                       0
# 5459         78.931818              176                       0
# 5460         89.436893              206                       0
# 5461        173.555556               90                       0
#
#       num_late_at_departure  avg_delay_late_at_departure  ...  \
# 0                        15                    11.550000  ...
# 1                        10                    14.653333  ...
# 2                        20                    13.694167  ...
# 3                        36                    20.988426  ...
# 4                        16                    20.963542  ...
# ...                     ...                          ...  ...
# 5457                    127                     5.837664  ...
# 5458                     13                     5.517949  ...
# 5459                     24                     9.431944  ...
# 5460                     15                     6.712222  ...
# 5461                      4                    10.150000  ...
#
#       delay_cause_traffic_management  delay_cause_rolling_stock  \
# 0                           0.166667                   0.416667
# 1                           0.125000                   0.125000
# 2                           0.071429                   0.285714
# 3                           0.310345                   0.344828
# 4                           0.250000                   0.305556
# ...                              ...                        ...
# 5457                        0.326087                   0.108696
# 5458                        0.080000                   0.240000
# 5459                        0.300000                   0.250000
# 5460                        0.250000                   0.500000
# 5461                        0.250000                   0.250000
#
#       delay_cause_station_management  delay_cause_travelers  \
# 0                           0.166667               0.000000
# 1                           0.062500               0.062500
# 2                           0.214286               0.000000
# 3                           0.034483               0.034483
# 4                           0.000000               0.027778
# ...                              ...                    ...
# 5457                        0.000000               0.086957
# 5458                        0.000000               0.040000
# 5459                        0.000000               0.000000
# 5460                        0.000000               0.000000
# 5461                        0.500000               0.000000
#
#       num_greater_15_min_late  avg_delay_late_greater_15_min  \
# 0                         6.0                      24.033333
# 1                         9.0                      21.498148
# 2                        14.0                      24.694048
# 3                        40.0                      34.047500
# 4                        26.0                      28.401282
# ...                       ...                            ...
# 5457                     15.0                       4.893003
# 5458                     25.0                       7.000936
# 5459                     10.0                       4.351136
# 5460                      4.0                       2.421278
# 5461                      1.0                       2.931111
#
#       num_greater_30_min_late  num_greater_60_min_late  departure_region  \
# 0                         1.0                      0.0               IDF
# 1                         1.0                      0.0                GE
# 2                         3.0                      0.0               IDF
# 3                        21.0                      5.0               IDF
# 4                         8.0                      1.0               IDF
# ...                       ...                      ...               ...
# 5457                      6.0                      1.0               NAq
# 5458                     10.0                      1.0                 O
# 5459                      5.0                      1.0               IDF
# 5460                      0.0                      0.0               IDF
# 5461                      0.0                      0.0                 B
#
#       arrival_region
# 0                 GE
# 1                IDF
# 2                 GE
# 3               PACA
# 4                ARA
# ...              ...
# 5457             IDF
# 5458             IDF
# 5459            CVDL
# 5460            PDLL
# 5461             IDF
#
# [5462 rows x 26 columns]

# %%
data['pct_cancelled'] = data['num_of_canceled_trains'] / data['total_num_trips']

# %%
data
# Out:
#       year  month   service   departure_station     arrival_station  \
# 0     2017      9  National           PARIS EST                METZ
# 1     2017      9  National               REIMS           PARIS EST
# 2     2017      9  National           PARIS EST          STRASBOURG
# 3     2017      9  National          PARIS LYON         AVIGNON TGV
# 4     2017      9  National          PARIS LYON    BELLEGARDE (AIN)
# ...    ...    ...       ...                 ...                 ...
# 5457  2018      9  National           ANGOULEME  PARIS MONTPARNASSE
# 5458  2018      9  National   TOULOUSE MATABIAU  PARIS MONTPARNASSE
# 5459  2018      9  National  PARIS MONTPARNASSE               TOURS
# 5460  2018      9  National  PARIS MONTPARNASSE               LAVAL
# 5461  2018      9  National             ST MALO  PARIS MONTPARNASSE
#
#       journey_time_avg  total_num_trips  num_of_canceled_trains  \
# 0            85.133779              299                       0
# 1            47.064516              218                       1
# 2           116.234940              333                       1
# 3           161.089583              481                       1
# 4           164.452632              190                       0
# ...                ...              ...                     ...
# 5457        130.690840              262                       0
# 5458        263.584270              178                       0
# 5459         78.931818              176                       0
# 5460         89.436893              206                       0
# 5461        173.555556               90                       0
#
#       num_late_at_departure  avg_delay_late_at_departure  ...  \
# 0                        15                    11.550000  ...
# 1                        10                    14.653333  ...
# 2                        20                    13.694167  ...
# 3                        36                    20.988426  ...
# 4                        16                    20.963542  ...
# ...                     ...                          ...  ...
# 5457                    127                     5.837664  ...
# 5458                     13                     5.517949  ...
# 5459                     24                     9.431944  ...
# 5460                     15                     6.712222  ...
# 5461                      4                    10.150000  ...
#
#       delay_cause_rolling_stock  delay_cause_station_management  \
# 0                      0.416667                        0.166667
# 1                      0.125000                        0.062500
# 2                      0.285714                        0.214286
# 3                      0.344828                        0.034483
# 4                      0.305556                        0.000000
# ...                         ...                             ...
# 5457                   0.108696                        0.000000
# 5458                   0.240000                        0.000000
# 5459                   0.250000                        0.000000
# 5460                   0.500000                        0.000000
# 5461                   0.250000                        0.500000
#
#       delay_cause_travelers  num_greater_15_min_late  \
# 0                  0.000000                      6.0
# 1                  0.062500                      9.0
# 2                  0.000000                     14.0
# 3                  0.034483                     40.0
# 4                  0.027778                     26.0
# ...                     ...                      ...
# 5457               0.086957                     15.0
# 5458               0.040000                     25.0
# 5459               0.000000                     10.0
# 5460               0.000000                      4.0
# 5461               0.000000                      1.0
#
#       avg_delay_late_greater_15_min  num_greater_30_min_late  \
# 0                         24.033333                      1.0
# 1                         21.498148                      1.0
# 2                         24.694048                      3.0
# 3                         34.047500                     21.0
# 4                         28.401282                      8.0
# ...                             ...                      ...
# 5457                       4.893003                      6.0
# 5458                       7.000936                     10.0
# 5459                       4.351136                      5.0
# 5460                       2.421278                      0.0
# 5461                       2.931111                      0.0
#
#       num_greater_60_min_late  departure_region  arrival_region  pct_cancelled
# 0                         0.0               IDF              GE       0.000000
# 1                         0.0                GE             IDF       0.004587
# 2                         0.0               IDF              GE       0.003003
# 3                         5.0               IDF            PACA       0.002079
# 4                         1.0               IDF             ARA       0.000000
# ...                       ...               ...             ...            ...
# 5457                      1.0               NAq             IDF       0.000000
# 5458                      1.0                 O             IDF       0.000000
# 5459                      1.0               IDF            CVDL       0.000000
# 5460                      0.0               IDF            PDLL       0.000000
# 5461                      0.0                 B             IDF       0.000000
#
# [5462 rows x 27 columns]

# %%
data_2018 = data[data.year==2018]
data_2018
# Out:
#       year  month   service   departure_station      arrival_station  \
# 3286  2018      6  National  PARIS MONTPARNASSE             POITIERS
# 3287  2018      6  National  PARIS MONTPARNASSE              QUIMPER
# 3288  2018      6  National  PARIS MONTPARNASSE               RENNES
# 3289  2018      6  National  PARIS MONTPARNASSE  ST PIERRE DES CORPS
# 3290  2018      6  National               TOURS   PARIS MONTPARNASSE
# ...    ...    ...       ...                 ...                  ...
# 5457  2018      9  National           ANGOULEME   PARIS MONTPARNASSE
# 5458  2018      9  National   TOULOUSE MATABIAU   PARIS MONTPARNASSE
# 5459  2018      9  National  PARIS MONTPARNASSE                TOURS
# 5460  2018      9  National  PARIS MONTPARNASSE                LAVAL
# 5461  2018      9  National             ST MALO   PARIS MONTPARNASSE
#
#       journey_time_avg  total_num_trips  num_of_canceled_trains  \
# 3286         94.334951              495                      83
# 3287        221.706161              255                      44
# 3288         97.607280              640                     118
# 3289         61.479876              392                      69
# 3290         75.554286              188                      13
# ...                ...              ...                     ...
# 5457        130.690840              262                       0
# 5458        263.584270              178                       0
# 5459         78.931818              176                       0
# 5460         89.436893              206                       0
# 5461        173.555556               90                       0
#
#       num_late_at_departure  avg_delay_late_at_departure  ...  \
# 3286                     25                    21.570667  ...
# 3287                     16                    16.307292  ...
# 3288                     38                    17.274123  ...
# 3289                     19                    22.894737  ...
# 3290                      3                     7.983333  ...
# ...                     ...                          ...  ...
# 5457                    127                     5.837664  ...
# 5458                     13                     5.517949  ...
# 5459                     24                     9.431944  ...
# 5460                     15                     6.712222  ...
# 5461                      4                    10.150000  ...
#
#       delay_cause_rolling_stock  delay_cause_station_management  \
# 3286                   0.148936                        0.000000
# 3287                   0.230769                        0.076923
# 3288                   0.263158                        0.052632
# 3289                   0.162791                        0.116279
# 3290                   0.115385                        0.000000
# ...                         ...                             ...
# 5457                   0.108696                        0.000000
# 5458                   0.240000                        0.000000
# 5459                   0.250000                        0.000000
# 5460                   0.500000                        0.000000
# 5461                   0.250000                        0.500000
#
#       delay_cause_travelers  num_greater_15_min_late  \
# 3286               0.063830                     23.0
# 3287               0.000000                     14.0
# 3288               0.013158                     34.0
# 3289               0.023256                     14.0
# 3290               0.000000                     12.0
# ...                     ...                      ...
# 5457               0.086957                     15.0
# 5458               0.040000                     25.0
# 5459               0.000000                     10.0
# 5460               0.000000                      4.0
# 5461               0.000000                      1.0
#
#       avg_delay_late_greater_15_min  num_greater_30_min_late  \
# 3286                       3.216505                     13.0
# 3287                       4.120853                      6.0
# 3288                       3.629885                     12.0
# 3289                       3.992931                      9.0
# 3290                       4.087238                      4.0
# ...                             ...                      ...
# 5457                       4.893003                      6.0
# 5458                       7.000936                     10.0
# 5459                       4.351136                      5.0
# 5460                       2.421278                      0.0
# 5461                       2.931111                      0.0
#
#       num_greater_60_min_late  departure_region  arrival_region  pct_cancelled
# 3286                      2.0               IDF             NAq       0.167677
# 3287                      2.0               IDF               B       0.172549
# 3288                      1.0               IDF               B       0.184375
# 3289                      3.0               IDF            CVDL       0.176020
# 3290                      0.0              CVDL             IDF       0.069149
# ...                       ...               ...             ...            ...
# 5457                      1.0               NAq             IDF       0.000000
# 5458                      1.0                 O             IDF       0.000000
# 5459                      1.0               IDF            CVDL       0.000000
# 5460                      0.0               IDF            PDLL       0.000000
# 5461                      0.0                 B             IDF       0.000000
#
# [1430 rows x 27 columns]

# %%
data_2018[['pct_cancelled', 'month']].groupby('month').mean()
# Out:
#        pct_cancelled
# month
# 1           0.007796
# 2           0.017953
# 3           0.022633
# 4           0.324225
# 5           0.233873
# 6           0.148433
# 7           0.047409
# 8           0.009452
# 9           0.004223
# 10          0.010203
# 11          0.010299

# %%
data[['year', 'pct_cancelled', 'month']].groupby(['year', 'month']).mean()
# Out:
#             pct_cancelled
# year month
# 2015 1           0.002834
#      2           0.002347
#      3           0.001065
#      4           0.001200
#      5           0.005357
#      6           0.001570
#      7           0.001926
#      8           0.002662
#      9           0.001567
#      10          0.005764
#      11          0.002003
#      12          0.002478
# 2016 1           0.001979
#      2           0.001846
#      3           0.024927
#      4           0.015685
#      5           0.001360
#      6           0.148363
#      7           0.002406
#      8           0.003176
#      9           0.001328
#      10          0.001698
#      11          0.002027
#      12          0.008142
# 2017 1           0.018010
#      2           0.005084
#      3           0.008239
#      4           0.006117
#      5           0.004764
#      6           0.006783
#      7           0.010265
#      8           0.019757
#      9           0.005462
#      10          0.005641
#      11          0.008422
#      12          0.012820
# 2018 1           0.007796
#      2           0.017953
#      3           0.022633
#      4           0.324225
#      5           0.233873
#      6           0.148433
#      7           0.047409
#      8           0.009452
#      9           0.004223
#      10          0.010203
#      11          0.010299

# %%
sns.heatmap(data[['year', 'pct_cancelled', 'month']].groupby(['year', 'month']).mean())
# Out:
# <AxesSubplot:ylabel='year-month'>

# %%
data[['year', 'pct_cancelled', 'month']].melt(id_vars=['year', 'month'])
# Out:
#       year  month       variable     value
# 0     2017      9  pct_cancelled  0.000000
# 1     2017      9  pct_cancelled  0.004587
# 2     2017      9  pct_cancelled  0.003003
# 3     2017      9  pct_cancelled  0.002079
# 4     2017      9  pct_cancelled  0.000000
# ...    ...    ...            ...       ...
# 5457  2018      9  pct_cancelled  0.000000
# 5458  2018      9  pct_cancelled  0.000000
# 5459  2018      9  pct_cancelled  0.000000
# 5460  2018      9  pct_cancelled  0.000000
# 5461  2018      9  pct_cancelled  0.000000
#
# [5462 rows x 4 columns]

# %%
data[['year', 'month', 'pct_cancelled']]
# Out:
#       year  month  pct_cancelled
# 0     2017      9       0.000000
# 1     2017      9       0.004587
# 2     2017      9       0.003003
# 3     2017      9       0.002079
# 4     2017      9       0.000000
# ...    ...    ...            ...
# 5457  2018      9       0.000000
# 5458  2018      9       0.000000
# 5459  2018      9       0.000000
# 5460  2018      9       0.000000
# 5461  2018      9       0.000000
#
# [5462 rows x 3 columns]

# %%
data[['year', 'month', 'pct_cancelled']].groupby(['year', 'month']).mean().unstack()
# Out:
#       pct_cancelled                                                    \
# month            1         2         3         4         5         6
# year
# 2015       0.002834  0.002347  0.001065  0.001200  0.005357  0.001570
# 2016       0.001979  0.001846  0.024927  0.015685  0.001360  0.148363
# 2017       0.018010  0.005084  0.008239  0.006117  0.004764  0.006783
# 2018       0.007796  0.017953  0.022633  0.324225  0.233873  0.148433
#
#
# month        7         8         9         10        11        12
# year
# 2015   0.001926  0.002662  0.001567  0.005764  0.002003  0.002478
# 2016   0.002406  0.003176  0.001328  0.001698  0.002027  0.008142
# 2017   0.010265  0.019757  0.005462  0.005641  0.008422  0.012820
# 2018   0.047409  0.009452  0.004223  0.010203  0.010299       NaN

# %%
sns.heatmap(data[['year', 'month', 'pct_cancelled']].groupby(['month', 'year']).mean().unstack())
# Out:
# <AxesSubplot:xlabel='None-year', ylabel='month'>

# %%
data[['year', 'month', 'pct_cancelled']].groupby(['month', 'year']).mean().unstack()
# Out:
#       pct_cancelled
# year           2015      2016      2017      2018
# month
# 1          0.002834  0.001979  0.018010  0.007796
# 2          0.002347  0.001846  0.005084  0.017953
# 3          0.001065  0.024927  0.008239  0.022633
# 4          0.001200  0.015685  0.006117  0.324225
# 5          0.005357  0.001360  0.004764  0.233873
# 6          0.001570  0.148363  0.006783  0.148433
# 7          0.001926  0.002406  0.010265  0.047409
# 8          0.002662  0.003176  0.019757  0.009452
# 9          0.001567  0.001328  0.005462  0.004223
# 10         0.005764  0.001698  0.005641  0.010203
# 11         0.002003  0.002027  0.008422  0.010299
# 12         0.002478  0.008142  0.012820       NaN

# %%
from sklearn.decomposition import PCA

# %%
data_2017 = data[data.year == 2017]

# %%
data_2017
# Out:
#       year  month        service departure_station       arrival_station  \
# 0     2017      9       National         PARIS EST                  METZ
# 1     2017      9       National             REIMS             PARIS EST
# 2     2017      9       National         PARIS EST            STRASBOURG
# 3     2017      9       National        PARIS LYON           AVIGNON TGV
# 4     2017      9       National        PARIS LYON      BELLEGARDE (AIN)
# ...    ...    ...            ...               ...                   ...
# 3908  2017      2       National       MONTPELLIER        LYON PART DIEU
# 3909  2017      2       National             LILLE  MARSEILLE ST CHARLES
# 3910  2017      2       National        STRASBOURG                NANTES
# 3911  2017      2  International         PARIS EST             STUTTGART
# 3912  2017      2  International            GENEVE            PARIS LYON
#
#       journey_time_avg  total_num_trips  num_of_canceled_trains  \
# 0            85.133779              299                       0
# 1            47.064516              218                       1
# 2           116.234940              333                       1
# 3           161.089583              481                       1
# 4           164.452632              190                       0
# ...                ...              ...                     ...
# 3908        112.488449              307                       4
# 3909        310.079710              138                       0
# 3910        306.457143               36                       1
# 3911        174.794240              136                       0
# 3912        188.128780              205                       0
#
#       num_late_at_departure  avg_delay_late_at_departure  ...  \
# 0                        15                    11.550000  ...
# 1                        10                    14.653333  ...
# 2                        20                    13.694167  ...
# 3                        36                    20.988426  ...
# 4                        16                    20.963542  ...
# ...                     ...                          ...  ...
# 3908                     33                    18.223232  ...
# 3909                     15                    13.526667  ...
# 3910                      2                     7.441667  ...
# 3911                      8                    15.852083  ...
# 3912                     11                    11.930303  ...
#
#       delay_cause_rolling_stock  delay_cause_station_management  \
# 0                      0.416667                        0.166667
# 1                      0.125000                        0.062500
# 2                      0.285714                        0.214286
# 3                      0.344828                        0.034483
# 4                      0.305556                        0.000000
# ...                         ...                             ...
# 3908                   0.121212                        0.060606
# 3909                   0.217391                        0.000000
# 3910                   0.000000                        0.000000
# 3911                   0.117647                        0.058824
# 3912                   0.105263                        0.052632
#
#       delay_cause_travelers  num_greater_15_min_late  \
# 0                  0.000000                      6.0
# 1                  0.062500                      9.0
# 2                  0.000000                     14.0
# 3                  0.034483                     40.0
# 4                  0.027778                     26.0
# ...                     ...                      ...
# 3908               0.000000                     38.0
# 3909               0.086957                     25.0
# 3910               0.000000                      4.0
# 3911               0.000000                     11.0
# 3912               0.105263                     14.0
#
#       avg_delay_late_greater_15_min  num_greater_30_min_late  \
# 0                         24.033333                      1.0
# 1                         21.498148                      1.0
# 2                         24.694048                      3.0
# 3                         34.047500                     21.0
# 4                         28.401282                      8.0
# ...                             ...                      ...
# 3908                      39.185526                     13.0
# 3909                      28.208000                      4.0
# 3910                      46.454167                      1.0
# 3911                      27.225758                      2.0
# 3912                      35.736905                      5.0
#
#       num_greater_60_min_late  departure_region  arrival_region  pct_cancelled
# 0                         0.0               IDF              GE       0.000000
# 1                         0.0                GE             IDF       0.004587
# 2                         0.0               IDF              GE       0.003003
# 3                         5.0               IDF            PACA       0.002079
# 4                         1.0               IDF             ARA       0.000000
# ...                       ...               ...             ...            ...
# 3908                      5.0                 O             IDF       0.013029
# 3909                      3.0               HDF            PACA       0.000000
# 3910                      1.0                GE            PDLL       0.027778
# 3911                      0.0               IDF       ALLEMAGNE       0.000000
# 3912                      2.0            SUISSE             IDF       0.000000
#
# [1344 rows x 27 columns]

# %%
data.columns
# Out:
# Index(['year', 'month', 'service', 'departure_station', 'arrival_station',
#        'journey_time_avg', 'total_num_trips', 'num_of_canceled_trains',
#        'num_late_at_departure', 'avg_delay_late_at_departure',
#        'avg_delay_all_departing', 'num_arriving_late',
#        'avg_delay_late_on_arrival', 'avg_delay_all_arriving',
#        'delay_cause_external_cause', 'delay_cause_rail_infrastructure',
#        'delay_cause_traffic_management', 'delay_cause_rolling_stock',
#        'delay_cause_station_management', 'delay_cause_travelers',
#        'num_greater_15_min_late', 'avg_delay_late_greater_15_min',
#        'num_greater_30_min_late', 'num_greater_60_min_late',
#        'departure_region', 'arrival_region', 'pct_cancelled'],
#       dtype='object')

# %%
data_acp = data_2017[['avg_delay_all_departing', 'pct_cancelled']]

# %%
data_acp
# Out:
#       avg_delay_all_departing  pct_cancelled
# 0                    0.752007       0.000000
# 1                    1.263518       0.004587
# 2                    1.139257       0.003003
# 3                    1.406215       0.002079
# 4                    1.728947       0.000000
# ...                       ...            ...
# 3908                 2.350990       0.013029
# 3909                 2.114372       0.000000
# 3910                 0.491905       0.027778
# 3911                 1.143750       0.000000
# 3912                 1.634309       0.000000
#
# [1344 rows x 2 columns]

# %%
greves = pd.read_csv('../data/greves-2015-2018.csv')

# %%
greves = greves.sort_values('Date').reset_index(drop=True)

# %%
greves['Journées perdues par agent'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.groupby(['year']).pct_cancelled.mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
data[data.year ==2018].groupby(['month']).pct_cancelled.mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='month'>

# %%
data.groupby('year').avg_delay_late_at_departure.mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
data.groupby('year').avg_delay_all_departing.mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
data
# Out:
#       year  month   service   departure_station     arrival_station  \
# 0     2017      9  National           PARIS EST                METZ
# 1     2017      9  National               REIMS           PARIS EST
# 2     2017      9  National           PARIS EST          STRASBOURG
# 3     2017      9  National          PARIS LYON         AVIGNON TGV
# 4     2017      9  National          PARIS LYON    BELLEGARDE (AIN)
# ...    ...    ...       ...                 ...                 ...
# 5457  2018      9  National           ANGOULEME  PARIS MONTPARNASSE
# 5458  2018      9  National   TOULOUSE MATABIAU  PARIS MONTPARNASSE
# 5459  2018      9  National  PARIS MONTPARNASSE               TOURS
# 5460  2018      9  National  PARIS MONTPARNASSE               LAVAL
# 5461  2018      9  National             ST MALO  PARIS MONTPARNASSE
#
#       journey_time_avg  total_num_trips  num_of_canceled_trains  \
# 0            85.133779              299                       0
# 1            47.064516              218                       1
# 2           116.234940              333                       1
# 3           161.089583              481                       1
# 4           164.452632              190                       0
# ...                ...              ...                     ...
# 5457        130.690840              262                       0
# 5458        263.584270              178                       0
# 5459         78.931818              176                       0
# 5460         89.436893              206                       0
# 5461        173.555556               90                       0
#
#       num_late_at_departure  avg_delay_late_at_departure  ...  \
# 0                        15                    11.550000  ...
# 1                        10                    14.653333  ...
# 2                        20                    13.694167  ...
# 3                        36                    20.988426  ...
# 4                        16                    20.963542  ...
# ...                     ...                          ...  ...
# 5457                    127                     5.837664  ...
# 5458                     13                     5.517949  ...
# 5459                     24                     9.431944  ...
# 5460                     15                     6.712222  ...
# 5461                      4                    10.150000  ...
#
#       delay_cause_rolling_stock  delay_cause_station_management  \
# 0                      0.416667                        0.166667
# 1                      0.125000                        0.062500
# 2                      0.285714                        0.214286
# 3                      0.344828                        0.034483
# 4                      0.305556                        0.000000
# ...                         ...                             ...
# 5457                   0.108696                        0.000000
# 5458                   0.240000                        0.000000
# 5459                   0.250000                        0.000000
# 5460                   0.500000                        0.000000
# 5461                   0.250000                        0.500000
#
#       delay_cause_travelers  num_greater_15_min_late  \
# 0                  0.000000                      6.0
# 1                  0.062500                      9.0
# 2                  0.000000                     14.0
# 3                  0.034483                     40.0
# 4                  0.027778                     26.0
# ...                     ...                      ...
# 5457               0.086957                     15.0
# 5458               0.040000                     25.0
# 5459               0.000000                     10.0
# 5460               0.000000                      4.0
# 5461               0.000000                      1.0
#
#       avg_delay_late_greater_15_min  num_greater_30_min_late  \
# 0                         24.033333                      1.0
# 1                         21.498148                      1.0
# 2                         24.694048                      3.0
# 3                         34.047500                     21.0
# 4                         28.401282                      8.0
# ...                             ...                      ...
# 5457                       4.893003                      6.0
# 5458                       7.000936                     10.0
# 5459                       4.351136                      5.0
# 5460                       2.421278                      0.0
# 5461                       2.931111                      0.0
#
#       num_greater_60_min_late  departure_region  arrival_region  pct_cancelled
# 0                         0.0               IDF              GE       0.000000
# 1                         0.0                GE             IDF       0.004587
# 2                         0.0               IDF              GE       0.003003
# 3                         5.0               IDF            PACA       0.002079
# 4                         1.0               IDF             ARA       0.000000
# ...                       ...               ...             ...            ...
# 5457                      1.0               NAq             IDF       0.000000
# 5458                      1.0                 O             IDF       0.000000
# 5459                      1.0               IDF            CVDL       0.000000
# 5460                      0.0               IDF            PDLL       0.000000
# 5461                      0.0                 B             IDF       0.000000
#
# [5462 rows x 27 columns]

# %%
from sklearn.cluster import KMeans

# %%
cls = KMeans(n_clusters=4)

# %%
greves
# Out:
#    Date  Journées perdues  Effectif à disposition  Journées perdues par agent
# 0  2015          97952.00                  151344                        0.69
# 1  2016         363425.00                  149808                        2.48
# 2  2017         112631.84                  144639                        0.78
# 3  2018         667085.00                  142236                        4.69

# %%
greves = greves.rename(columns={'Date': 'year'})

# %%
data[['year', 'month', 'pct_cancelled']].groupby(['year','month']).mean()
# Out:
#             pct_cancelled
# year month
# 2015 1           0.002834
#      2           0.002347
#      3           0.001065
#      4           0.001200
#      5           0.005357
#      6           0.001570
#      7           0.001926
#      8           0.002662
#      9           0.001567
#      10          0.005764
#      11          0.002003
#      12          0.002478
# 2016 1           0.001979
#      2           0.001846
#      3           0.024927
#      4           0.015685
#      5           0.001360
#      6           0.148363
#      7           0.002406
#      8           0.003176
#      9           0.001328
#      10          0.001698
#      11          0.002027
#      12          0.008142
# 2017 1           0.018010
#      2           0.005084
#      3           0.008239
#      4           0.006117
#      5           0.004764
#      6           0.006783
#      7           0.010265
#      8           0.019757
#      9           0.005462
#      10          0.005641
#      11          0.008422
#      12          0.012820
# 2018 1           0.007796
#      2           0.017953
#      3           0.022633
#      4           0.324225
#      5           0.233873
#      6           0.148433
#      7           0.047409
#      8           0.009452
#      9           0.004223
#      10          0.010203
#      11          0.010299

# %%
print(greves)
kmeans_data = data[['year', 'month', 'pct_cancelled']].groupby('year').pct_cancelled.mean()
# Out:
#    year  Journées perdues  Effectif à disposition  Journées perdues par agent
# 0  2015          97952.00                  151344                        0.69
# 1  2016         363425.00                  149808                        2.48
# 2  2017         112631.84                  144639                        0.78
# 3  2018         667085.00                  142236                        4.69

# %%
type(kmeans_data)
# Out:
# pandas.core.series.Series

# %%
kmeans_data
# Out:
# year
# 2015    0.002564
# 2016    0.017745
# 2017    0.009280
# 2018    0.076045
# Name: pct_cancelled, dtype: float64

# %%
greves = greves.drop(columns=['Journées perdues', 'Effectif à disposition'])

# %%
greves
# Out:
#    year  Journées perdues par agent
# 0  2015                        0.69
# 1  2016                        2.48
# 2  2017                        0.78
# 3  2018                        4.69

# %%
greves = greves.set_index('year')

# %%
kmeans_data = pd.DataFrame({'strike_days': greves['Journées perdues par agent'], 'pct_cancelled': kmeans_data})

# %%
kmeans_data
# Out:
#       strike_days  pct_cancelled
# year
# 2015         0.69       0.002564
# 2016         2.48       0.017745
# 2017         0.78       0.009280
# 2018         4.69       0.076045

# %%
sns.scatterplot(data=kmeans_data, x='strike_days', y='pct_cancelled')
# Out:
# <AxesSubplot:xlabel='strike_days', ylabel='pct_cancelled'>

# %%
strikes_per_month = pd.read_csv('../data/mouvements-sociaux-depuis-1994.csv', sep=';')

# %%
strikes_per_month
# Out:
#         Date  Journées perdues
# 0    1994-04           7869.00
# 1    1994-07           2860.00
# 2    1994-09           1424.00
# 3    1995-01           6442.00
# 4    1995-02           3643.00
# ..       ...               ...
# 331  2019-01            729.38
# 332  2019-12         327141.00
# 333  2020-01         158241.38
# 334  2021-01           2317.75
# 335  2021-02           4021.00
#
# [336 rows x 2 columns]

# %%
strikes_per_month.Date.str.split('-')
# Out:
# 0      [1994, 04]
# 1      [1994, 07]
# 2      [1994, 09]
# 3      [1995, 01]
# 4      [1995, 02]
#           ...
# 331    [2019, 01]
# 332    [2019, 12]
# 333    [2020, 01]
# 334    [2021, 01]
# 335    [2021, 02]
# Name: Date, Length: 336, dtype: object

# %%
strikes_per_month[['year','month']] = pd.DataFrame(strikes_per_month.Date.str.split('-').tolist(), index= strikes_per_month.index)

# %%
strikes_per_month = strikes_per_month.drop(columns=['Date'])

# %%
strikes_per_month[strikes_per_month.year > '2015']
# Out:
#      Journées perdues  year month
# 53            7017.00  2016    02
# 54            2197.00  2016    07
# 55            1555.00  2016    08
# 56           12552.01  2017    02
# 57            1417.26  2017    05
# ..                ...   ...   ...
# 331            729.38  2019    01
# 332         327141.00  2019    12
# 333         158241.38  2020    01
# 334           2317.75  2021    01
# 335           4021.00  2021    02
#
# [72 rows x 3 columns]

# %%
strikes_per_month['year'] = strikes_per_month['year'].astype(int)
strikes_per_month['month'] = strikes_per_month['month'].astype(int)

# %%
strikes_per_month
# Out:
#      Journées perdues  year  month
# 0             7869.00  1994      4
# 1             2860.00  1994      7
# 2             1424.00  1994      9
# 3             6442.00  1995      1
# 4             3643.00  1995      2
# ..                ...   ...    ...
# 331            729.38  2019      1
# 332         327141.00  2019     12
# 333         158241.38  2020      1
# 334           2317.75  2021      1
# 335           4021.00  2021      2
#
# [336 rows x 3 columns]

# %%
strikes_per_month = strikes_per_month[(strikes_per_month.year > 2014) & (strikes_per_month.year < 2019)].sort_values(['year', 'month'])

# %%
strikes_per_month = strikes_per_month.reset_index()

# %%
strikes_per_month = strikes_per_month.drop(columns=['index'])

# %%
strikes_per_month = strikes_per_month[['year', 'month', 'Journées perdues']]

# %%
strikes_per_month = strikes_per_month.groupby(['year', 'month']).mean()

# %%
kmeans_data = data[['year', 'month', 'pct_cancelled']].groupby(['year','month']).pct_cancelled.mean()

# %%
kmeans_data = pd.DataFrame(kmeans_data)

# %%
type(strikes_per_month)
# Out:
# pandas.core.frame.DataFrame

# %%
strikes_per_month
# Out:
#             Journées perdues
# year month
# 2015 1              10355.00
#      2               2387.00
#      3              17168.00
#      4              14169.00
#      5               2128.00
#      6              17072.00
#      7               4135.00
#      8               3238.00
#      9               1845.00
#      10             17234.00
#      11              2069.00
#      12              6152.00
# 2016 1               3226.00
#      2               7017.00
#      3              74194.00
#      4              45871.00
#      5              76058.00
#      6             140169.00
#      7               2197.00
#      8               1555.00
#      9               4159.00
#      10              1178.00
#      11              2033.00
#      12              5769.00
# 2017 1               1329.13
#      2              12552.01
#      3               6827.39
#      4               4228.38
#      5               1417.26
#      6               9121.01
#      7               4103.26
#      8               2996.38
#      9              35022.88
#      10             16576.63
#      11             13272.26
#      12              5185.25
# 2018 1               2258.13
#      2               8313.38
#      3              43787.01
#      4             237672.25
#      5             187473.12
#      6             140809.25
#      7              20690.88
#      8               1253.13
#      9               1108.88
#      10             11047.00
#      11              2667.75
#      12             10004.38

# %%
strikes_per_month['Journées perdues'].dtype
# Out:
# dtype('float64')

# %%
kmeans_data['pct_cancelled'].dtype
# Out:
# dtype('float64')

# %%
kmeans_data
# Out:
#             pct_cancelled
# year month
# 2015 1           0.002834
#      2           0.002347
#      3           0.001065
#      4           0.001200
#      5           0.005357
#      6           0.001570
#      7           0.001926
#      8           0.002662
#      9           0.001567
#      10          0.005764
#      11          0.002003
#      12          0.002478
# 2016 1           0.001979
#      2           0.001846
#      3           0.024927
#      4           0.015685
#      5           0.001360
#      6           0.148363
#      7           0.002406
#      8           0.003176
#      9           0.001328
#      10          0.001698
#      11          0.002027
#      12          0.008142
# 2017 1           0.018010
#      2           0.005084
#      3           0.008239
#      4           0.006117
#      5           0.004764
#      6           0.006783
#      7           0.010265
#      8           0.019757
#      9           0.005462
#      10          0.005641
#      11          0.008422
#      12          0.012820
# 2018 1           0.007796
#      2           0.017953
#      3           0.022633
#      4           0.324225
#      5           0.233873
#      6           0.148433
#      7           0.047409
#      8           0.009452
#      9           0.004223
#      10          0.010203
#      11          0.010299

# %%
kmeans_data.loc[:, 'strike_days'] = strikes_per_month['Journées perdues']

# %%
kmeans_data.index.names
# Out:
# FrozenList(['year', 'month'])

# %%
strikes_per_month.index.names
# Out:
# FrozenList(['year', 'month'])

# %%
strikes_per_month.iloc[0]
# Out:
# Journées perdues    10355.0
# Name: (2015, 1), dtype: float64

# %%
kmeans_data.iloc[0]
# Out:
# pct_cancelled        0.002834
# strike_days      10355.000000
# Name: (2015, 1), dtype: float64

# %%
strikes_per_month = strikes_per_month.drop(strikes_per_month.index[[47]])

# %%
kmeans_data
# Out:
#             pct_cancelled  strike_days
# year month
# 2015 1           0.002834     10355.00
#      2           0.002347      2387.00
#      3           0.001065     17168.00
#      4           0.001200     14169.00
#      5           0.005357      2128.00
#      6           0.001570     17072.00
#      7           0.001926      4135.00
#      8           0.002662      3238.00
#      9           0.001567      1845.00
#      10          0.005764     17234.00
#      11          0.002003      2069.00
#      12          0.002478      6152.00
# 2016 1           0.001979      3226.00
#      2           0.001846      7017.00
#      3           0.024927     74194.00
#      4           0.015685     45871.00
#      5           0.001360     76058.00
#      6           0.148363    140169.00
#      7           0.002406      2197.00
#      8           0.003176      1555.00
#      9           0.001328      4159.00
#      10          0.001698      1178.00
#      11          0.002027      2033.00
#      12          0.008142      5769.00
# 2017 1           0.018010      1329.13
#      2           0.005084     12552.01
#      3           0.008239      6827.39
#      4           0.006117      4228.38
#      5           0.004764      1417.26
#      6           0.006783      9121.01
#      7           0.010265      4103.26
#      8           0.019757      2996.38
#      9           0.005462     35022.88
#      10          0.005641     16576.63
#      11          0.008422     13272.26
#      12          0.012820      5185.25
# 2018 1           0.007796      2258.13
#      2           0.017953      8313.38
#      3           0.022633     43787.01
#      4           0.324225    237672.25
#      5           0.233873    187473.12
#      6           0.148433    140809.25
#      7           0.047409     20690.88
#      8           0.009452      1253.13
#      9           0.004223      1108.88
#      10          0.010203     11047.00
#      11          0.010299      2667.75

# %%
sns.scatterplot(data=kmeans_data[kmeans_data.index.get_level_values('year') == 2018], x='strike_days', y='pct_cancelled')
# Out:
# <AxesSubplot:xlabel='strike_days', ylabel='pct_cancelled'>

# %%
kmeans_data.index.names[0]
# Out:
# 'year'

# %%
kmeans_data[kmeans_data.index.get_level_values('year') == 2015]
# Out:
#             pct_cancelled  strike_days
# year month
# 2015 1           0.002834      10355.0
#      2           0.002347       2387.0
#      3           0.001065      17168.0
#      4           0.001200      14169.0
#      5           0.005357       2128.0
#      6           0.001570      17072.0
#      7           0.001926       4135.0
#      8           0.002662       3238.0
#      9           0.001567       1845.0
#      10          0.005764      17234.0
#      11          0.002003       2069.0
#      12          0.002478       6152.0

# %%
kmeans_data = kmeans_data[kmeans_data.index.get_level_values('year') == 2015].reset_index()

# %%
cls = KMeans(n_clusters=12)

# %%
cls.fit(kmeans_data[['pct_cancelled', 'strike_days']])
# Out:
# KMeans(n_clusters=12)

# %%
cls.labels_
# Out:
# array([ 3,  7,  2,  1, 11,  9,  6,  0,  8, 10,  5,  4])

# %%
sns.scatterplot(data=kmeans_data, x='pct_cancelled', y='strike_days', hue=cls.labels_)
# Out:
# <AxesSubplot:xlabel='pct_cancelled', ylabel='strike_days'>
