# %%
import pandas as pd

# %%
data = pd.read_csv('../data/full_trains_fixed.csv')

# %%
data
# Out:
#       year  month   service   departure_station     arrival_station  \
# 0     2017      9  National           PARIS EST                METZ
# 1     2017      9  National               REIMS           PARIS EST
# 2     2017      9  National           PARIS EST          STRASBOURG
# 3     2017      9  National          PARIS LYON         AVIGNON TGV
# 4     2017      9  National          PARIS LYON    BELLEGARDE (AIN)
# ...    ...    ...       ...                 ...                 ...
# 5457  2018      9  National           ANGOULEME  PARIS MONTPARNASSE
# 5458  2018      9  National   TOULOUSE MATABIAU  PARIS MONTPARNASSE
# 5459  2018      9  National  PARIS MONTPARNASSE               TOURS
# 5460  2018      9  National  PARIS MONTPARNASSE               LAVAL
# 5461  2018      9  National             ST MALO  PARIS MONTPARNASSE
#
#       journey_time_avg  total_num_trips  num_of_canceled_trains  \
# 0            85.133779              299                       0
# ...

# %%
data[data.departure_region.isna()].departure_station.unique()
# Out:
# array([], dtype=object)

# %%
data_s = data[(data.departure_region == 'NAq') | (data.departure_region == 'O') | (data.departure_region == 'PACA')]

# %%
data_s
# Out:
#       year  month   service     departure_station     arrival_station  \
# 11    2017      9  National           MONTPELLIER          PARIS LYON
# 15    2017      9  National      BORDEAUX ST JEAN  PARIS MONTPARNASSE
# 16    2017      9  National     LA ROCHELLE VILLE  PARIS MONTPARNASSE
# 18    2017      9  National              POITIERS  PARIS MONTPARNASSE
# 28    2017      1  National  MARSEILLE ST CHARLES          PARIS LYON
# ...    ...    ...       ...                   ...                 ...
# 5431  2018     11  National           MONTPELLIER      LYON PART DIEU
# 5445  2018      9  National   AIX EN PROVENCE TGV          PARIS LYON
# 5446  2018      9  National                 NIMES          PARIS LYON
# 5457  2018      9  National             ANGOULEME  PARIS MONTPARNASSE
# 5458  2018      9  National     TOULOUSE MATABIAU  PARIS MONTPARNASSE
#
#       journey_time_avg  total_num_trips  num_of_canceled_trains  \
# ...

# %%
data_s = data_s.reset_index()

# %%
data_s = data_s.drop(columns=['index'])

# %%
data_s
# Out:
#      year  month   service     departure_station     arrival_station  \
# 0    2017      9  National           MONTPELLIER          PARIS LYON
# 1    2017      9  National      BORDEAUX ST JEAN  PARIS MONTPARNASSE
# 2    2017      9  National     LA ROCHELLE VILLE  PARIS MONTPARNASSE
# 3    2017      9  National              POITIERS  PARIS MONTPARNASSE
# 4    2017      1  National  MARSEILLE ST CHARLES          PARIS LYON
# ..    ...    ...       ...                   ...                 ...
# 802  2018     11  National           MONTPELLIER      LYON PART DIEU
# 803  2018      9  National   AIX EN PROVENCE TGV          PARIS LYON
# 804  2018      9  National                 NIMES          PARIS LYON
# 805  2018      9  National             ANGOULEME  PARIS MONTPARNASSE
# 806  2018      9  National     TOULOUSE MATABIAU  PARIS MONTPARNASSE
#
#      journey_time_avg  total_num_trips  num_of_canceled_trains  \
# 0          205.816568              341                       3
# ...

# %%
data_s.avg_delay_all_arriving.mean()
# Out:
# 7.186334396037862

# %%
data_s.avg_delay_all_departing.mean()
# Out:
# 3.36119934811756

# %%
data_s.avg_delay_late_at_departure.mean()
# Out:
# 17.013746467856425

# %%
data_s.avg_delay_late_on_arrival.mean()
# Out:
# 38.430065495390195

# %%
data.columns
# Out:
# Index(['year', 'month', 'service', 'departure_station', 'arrival_station',
#        'journey_time_avg', 'total_num_trips', 'num_of_canceled_trains',
#        'num_late_at_departure', 'avg_delay_late_at_departure',
#        'avg_delay_all_departing', 'num_arriving_late',
#        'avg_delay_late_on_arrival', 'avg_delay_all_arriving',
#        'delay_cause_external_cause', 'delay_cause_rail_infrastructure',
#        'delay_cause_traffic_management', 'delay_cause_rolling_stock',
#        'delay_cause_station_management', 'delay_cause_travelers',
#        'num_greater_15_min_late', 'avg_delay_late_greater_15_min',
#        'num_greater_30_min_late', 'num_greater_60_min_late',
#        'departure_region', 'arrival_region'],
#       dtype='object')

# %%
data_s[['']]
